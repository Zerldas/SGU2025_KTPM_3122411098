# %%
# !sudo apt update
# !sudo apt install g++
# Out:
# Get:1 https://packages.microsoft.com/repos/microsoft-ubuntu-noble-prod noble InRelease [3600 B]
# Get:2 https://dl.yarnpkg.com/debian stable InRelease
# Get:3 https://packages.microsoft.com/repos/microsoft-ubuntu-noble-prod noble/main all Packages [643 B]
# Get:4 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease [3961 B]0m
# Get:5 https://packages.microsoft.com/repos/microsoft-ubuntu-noble-prod noble/main amd64 Packages [50.3 kB]
# Get:6 https://dl.yarnpkg.com/debian stable/main amd64 Packages [11.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble InRelease [256 kB]     m
# Get:8 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:9 https://dl.yarnpkg.com/debian stable/main all Packages [11.8 kB]
# Get:10 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable/main amd64 Packages [4557 B]m
# Get:11 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [2159 kB]3m
# ...

# %%
# !g++ f1.cpp -o f1
# Out:
# /usr/bin/ld: /usr/lib/gcc/x86_64-linux-gnu/13/../../../x86_64-linux-gnu/Scrt1.o: in function `_start':
# (.text+0x1b): undefined reference to `main'
# collect2: error: ld returned 1 exit status
# /bin/bash: line 1: ./f1: No such file or directory
